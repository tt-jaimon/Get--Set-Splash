# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cause = pd.read_csv('causeofdeath-vic-2009-2018.csv')
cause.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#Predefined Function to calculate the ticks and its name for various Axis's
#Based on the min and max values of the array given
def findAxisCordinatesAndNamesForTicks(Values = [],formatValue = 1,divisions = 20,overallMin = -1,overallMax=-1):
    if(overallMin == -1):
        overallMin = Values.agg('min')
    if(overallMax == -1):
        overallMax = Values.agg('max')
    #Finding the y axis label
    axis = []
    axisVariableNames = []
    i = int(overallMin)
    diff = (overallMax - overallMin)/divisions
    if(diff > (int(diff)+ 0.5)):
        diff = int(diff + 1)
    elif(diff > 1):
        diff = int(diff)
    diff = round(diff,2)
    while(i < overallMax + diff):
        i = round(i,2)
        axis.append(i)
        if(formatValue != 1):
            axisVariableNames.append(str(i/formatValue))
        else : 
            axisVariableNames.append(str(i))
        i += diff
    return [axis,axisVariableNames]

# %%
cause.head()
# Out:
#                       Cause of death and ICD-10 code Gender  Deaths  year
# 0  accident to watercraft causing drowning and su...   Male       1  2009
# 1  water-transport-related drowning and submersio...   Male       2  2009
# 2  accident on board watercraft without accident ...   Male       0  2009
# 3  diving or jumping into water causing injury ot...   Male       0  2009
# 4       accidental drowning and submersion (w65-w74)   Male      19  2009

# %%
cause.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
# Out:
#                        Cause of death and ICD-10 code  Deaths
# 0   accident on board watercraft without accident ...      16
# 1   accident to watercraft causing drowning and su...      48
# 2        accidental drowning and submersion (w65-w74)     584
# 3            assault by drowning and submersion (x92)       0
# 4   diving or jumping into water causing injury ot...      24
# 5   drowning and submersion following fall into ba...      23
# 6   drowning and submersion following fall into na...      96
# 7   drowning and submersion following fall into sw...      49
# 8     drowning and submersion while in bath-tub (w65)      47
# 9   drowning and submersion while in natural water...     313
# 10  drowning and submersion while in swimming-pool...      54
# 11  drowning and submersion, undetermined intent (...      81
# 12  intentional self-harm by drowning and submersi...     194
# 13      other specified drowning and submersion (w73)      44
# ...

# %%
causeGrouped = cause.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths',fontsize=20)
plt.show()

# %%
causeMale = cause[cause['Gender'] == 'Male']
causeFemale = cause[cause['Gender'] == 'Female']
causePerson = cause[cause['Gender'] == 'Person']

# %%
causeGrouped = causeMale.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths for Male',fontsize=20)
plt.show()

# %%
causeGrouped = causeFemale.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths for Female',fontsize=20)
plt.show()

# %%
causeGrouped = causeFemale.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths for Person',fontsize=20)
plt.show()

# %%
cause.head()
# Out:
#                       Cause of death and ICD-10 code Gender  Deaths  year
# 0  accident to watercraft causing drowning and su...   Male       1  2009
# 1  water-transport-related drowning and submersio...   Male       2  2009
# 2  accident on board watercraft without accident ...   Male       0  2009
# 3  diving or jumping into water causing injury ot...   Male       0  2009
# 4       accidental drowning and submersion (w65-w74)   Male      19  2009

# %%
causeGrouped = cause.groupby(['Gender'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Gender',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths -2018',fontsize=20)
plt.show()

# %%
temp = cause[['Gender','year','Deaths']].groupby(['Gender','year']).agg('sum').reset_index()
groupedInfo = temp.groupby('Gender')

yAxis, yAxisVariableNames = findAxisCordinatesAndNamesForTicks(temp['Deaths'])

#Finding the x axis label
ticks = findAxisCordinatesAndNamesForTicks(cause['year'],divisions = 10)
xAxis = ticks[0]
xAxisVariableNames =ticks[1]  

plt.figure(figsize = (20,10))

for gender,info in groupedInfo:
    plt.plot(info.year,info.Deaths, label = gender, linewidth = 1.0)

plt.xticks(xAxis, xAxisVariableNames, rotation = 45, fontsize = 15)
plt.yticks(yAxis, yAxisVariableNames, fontsize = 15)

plt.ylabel('Deaths', fontsize=18)
plt.xlabel('year', fontsize=18)
plt.title('Deaths vs year based on Cause', fontsize=20)
plt.legend(loc= 'upper center', ncol=3, fancybox = True, shadow = True, bbox_to_anchor = (0.5, 1.15), fontsize = 15)

plt.grid()
plt.show()

# %% [markdown]
# ## 2018 data

# %%
causeGrouped = cause2018.groupby(['Gender'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Gender',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths -2018',fontsize=20)
plt.show()

# %%
cause2018 = cause[cause['year'] == 2018]
causeMale2018 = cause[(cause['Gender'] == 'Male') & (cause['year'] == 2018)]
causeFemale2018 = cause[(cause['Gender'] == 'Female') &(cause['year'] == 2018) ]
causePerson2018 = cause[(cause['Gender'] == 'Person') & (cause['year'] == 2018)]

# %%
causeGrouped = cause2018.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths -2018',fontsize=20)
plt.show()

# %%
causeGrouped = causeMale2018.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths - Male -2018',fontsize=20)
plt.show()

# %%
causeFemale2018.head()
# Out:
#                         Cause of death and ICD-10 code  Gender  Deaths  year
# 448  accident to watercraft causing drowning and su...  Female       0  2018
# 449  water-transport-related drowning and submersio...  Female       4  2018
# 450  accident on board watercraft without accident ...  Female       0  2018
# 451  diving or jumping into water causing injury ot...  Female       0  2018
# 452       accidental drowning and submersion (w65-w74)  Female       6  2018

# %%
causeGrouped = causeFemale2018.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths - Female -2018',fontsize=20)
plt.show()

# %%
causeGrouped = causePerson2018.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
plt.ylabel('Deaths',fontsize=18)
plt.xlabel('Cause of death and ICD-10 code',fontsize=18)
plt.title('Cause of death and ICD-10 code Vs Deaths - Person -2018',fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-65bd7d9a6112> in <module>()
# ----> 1 causeGrouped = causePerson2018.groupby(['Cause of death and ICD-10 code'])['Deaths'].agg('sum').reset_index()
#       2 causeGrouped = causeGrouped[causeGrouped['Cause of death and ICD-10 code']!='accidental drowning and submersion (w65-w74)']
#       3 causeGrouped = causeGrouped.sort_values(by=['Deaths'],ascending =False)
#       4 causeGrouped.plot.bar(x='Cause of death and ICD-10 code',y='Deaths',figsize=(15, 10),fontsize=12,legend=None)
#       5 plt.ylabel('Deaths',fontsize=18)
#
# NameError: name 'causePerson2018' is not defined
